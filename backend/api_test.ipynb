# %%
import requests
import pandas as pd
from datetime import datetime
import json

# %%
# API base URL
BASE_URL = "http://127.0.0.1:8000"

# %%
# Second cell - get today's plants
response = requests.get(f"{BASE_URL}/api/plants/today")
plants = response.json()

# %%
# Convert to DataFrame for better visualization
df = pd.DataFrame(plants)
df
# Out:
#    id                            name last_watered last_fertilized  \
# 0   1               Calathea Medalion         None            None
# 1   2               Clathea Orbifolia         None            None
# 2   3                  Coffea Arabica         None            None
# 3   4                Epiprenum Aureum         None            None
# 4   5              Monstera Adenossii         None            None
# 5   6  Philodendron Hedaracium Brasil         None            None
# 6   7   Philodendron Scandens Micans          None            None
# 7   8    Scindapsus Treubii Moonlight         None            None
#
#   days_since_watering days_since_fertilizing  watering_schedule  \
# 0                None                   None                  7
# 1                None                   None                  7
# 2                None                   None                  7
# 3                None                   None                  7
# 4                None                   None                  7
# 5                None                   None                  7
# 6                None                   None                  7
# 7                None                   None                  7
#
#    fertilizing_schedule  needs_water  needs_fertilizer
# 0                    14        False             False
# 1                    14        False             False
# 2                    14        False             False
# 3                    14        False             False
# 4                    14        False             False
# 5                    14        False             False
# 6                    14        False             False
# 7                    14        False             False
